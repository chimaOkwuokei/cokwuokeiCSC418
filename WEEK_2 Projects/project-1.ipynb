# %% [markdown]
# ### Project 1

# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
def get_image(features):
    for name, names in members.items():
        if all(features.get(key, False) == value for key, value in names.items()):
            image_name = names['firstname']
            extensions = ["jpg", "png"]

            for ext in extensions:
                image = cv2.imread(f'img/{image_name}.{ext}')
                if image is not None:  # Check if image is loaded
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
                    plt.subplot(1, 2, 1)
                    plt.title("Original")
                    plt.imshow(image)
                    plt.show() #ensures the image is displayed
                    return name
    return 'Member does not exist or member does not have an image'

# %%
# PAU-UMC Application
members = {
    "Enase": {"firstname": "enase", "lastname": len("Okonedo")},
    "Chris": {"firstname": "chris", "lastname": len("Ogbechie")},
    "Kingsley": {"firstname": "kingsley", "lastname": len("Ukaoha")},
    "Donatus": {"firstname": "donatus", "lastname": len("Ogbuike")},
    "Ikechukwu": {"firstname": "ikechukwu", "lastname": len("Obiaya")},
    "Sola": {"firstname": "sola", "lastname": len("Oni")},
    "Darlington": {"firstname": "darlington", "lastname": len("Agholor")},
    "Nneka": {"firstname": "nneka", "lastname": len("Okekearu")},
    "Adaora": {"firstname": "adaora", "lastname": len("Onaga")},
    "Peter": {"firstname": "peter", "lastname": len("Bamkole")},
}

username = input("Enter your username(firstname): ")
password = int(input("Enter your password (sum of numbers of alphabets in your surname): "))


features = {"firstname":username, "lastname":password}
# print(features)

get_image(features)
# Out:
# Enter your username(firstname):  peter
# Enter your password (sum of numbers of alphabets in your surname):  7
# 'Peter'
