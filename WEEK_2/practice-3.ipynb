# %% [markdown]
# ### Practice 3 - Brightness and Contrast

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#load the image
image = cv2.imread('img/sst.png')

plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)

#adjust the brightness and contrast
brightness = 5
contrast = 1.5
image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape, image.dtype), 0, brightness)

#save teh image
cv2.imwrite('img/contrast_image.jpg', image2)

#plot the contrast image
plt.subplot(1,2,2)
plt.title("Brightness & Contrast")
plt.imshow(image2)
plt.show()
