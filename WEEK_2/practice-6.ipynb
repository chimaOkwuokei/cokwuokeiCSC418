# %% [markdown]
# ### Practice 6 - Image Scaling

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#load the image
image = cv2.imread('img/sst-foyer.jpg')

# %%
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)

#scaled the image
scaled_image = cv2.resize(image, None, fx=10, fy=10)

#save the image
cv2.imwrite('img/Scaled.jpg', scaled_image)

#plot the scaled image
plt.subplot(1,2,2)
plt.title("Scaled")
plt.imshow(scaled_image)
plt.show()
