# %% [markdown]
# ### Practice 7 - Inverse Transform

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#load the image
image = cv2.imread('img/sst-foyer.jpg')

# %%
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)

#inverse the image
inverse_image = 239 - image

#save the image
cv2.imwrite('img/inverse_image.jpg', inverse_image)

#plot the inverse image
plt.subplot(1,2,2)
plt.title("Inverese")
plt.imshow(inverse_image)
plt.show()
